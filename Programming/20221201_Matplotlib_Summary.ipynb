# %%
import matplotlib.pyplot as plt

# %%
#Line Graph.
plt.plot([0,1,2,3], [0,2,4,6], label='f(x)=2x', color='red', linewidth=3, linestyle='--', marker='.', markersize=20)
#plt.plot([0,1,2,3], [0,2,4,6], 'b^-')      #color, marker, line (concise version).

plt.title('Line Graph', fontdict={'fontsize': 30, 'fontweight':'bold'})

plt.xlabel('Number')         #x axis.
plt.ylabel('2 x Number')     #y axis. 

plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8])

plt.legend()                 #label required first.

plt.figure(figsize=(5,3))    #resize.

plt.show()

# %%
#Bar Chart.
plt.bar(['a', 'b', 'c'], [1,4,2])

plt.show()

# %%
#Histogram.
plt.hist([1,1,1,1,2,2,2,3,3,4,5,8,10], bins=[0,3,6,9])    #bins: set category.
plt.xticks([0,3,6,9])

plt.show()

# %%
#Pie Chart.
plt.pie([150, 360], labels=['male', 'female'], colors=['red', 'green'], autopct='%.2f %%')

plt.show()
